# %% [markdown]
# ## 1. Kütüphane Import İşlemleri

# %%
import requests
from bs4 import BeautifulSoup as bts
import pandas as pd
import re
import numpy as np
import time, os

# %% [markdown]
# ## 2. İstek Atacak Fonksiyonun Oluşturulması

# %%
def getAndParseURL(url):
    result = requests.get(url, headers={"User-Agent":"Safari/537.36."})
    soup = bts(result.text, "html.parser")
    return soup

# %% [markdown]
# ## 3.Sayfa Linklerinin Elde Edilmesi

# %%
pages = ["https://www.arabam.com/ikinci-el/otomobil/skoda?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50","https://www.arabam.com/ikinci-el/otomobil/toyota?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50","https://www.arabam.com/ikinci-el/otomobil/volkswagen?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50","https://www.arabam.com/ikinci-el/otomobil/renault?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50","https://www.arabam.com/ikinci-el/otomobil/opel?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50","https://www.arabam.com/ikinci-el/otomobil/fiat?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50","https://www.arabam.com/ikinci-el/otomobil/ford?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50"]

# %%
skoda = ["https://www.arabam.com/ikinci-el/otomobil/skoda?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50"]

# %%
skoda_links= []
for sayi in range(1,51):
    url = "https://www.arabam.com/ikinci-el/otomobil/skoda?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=" + str(sayi)
    skoda_links.append(url)

print(skoda_links)
# Out:
# ['https://www.arabam.com/ikinci-el/otomobil/skoda?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=1', 'https://www.arabam.com/ikinci-el/otomobil/skoda?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=2', 'https://www.arabam.com/ikinci-el/otomobil/skoda?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=3', 'https://www.arabam.com/ikinci-el/otomobil/skoda?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=4', 'https://www.arabam.com/ikinci-el/otomobil/skoda?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=5', 'https://www.arabam.com/ikinci-el/otomobil/skoda?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=6', 'https://www.arabam.com/ikinci-el/otomobil/skoda?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=7', 'https://www.arabam.com/ikinci-el/otomobil/skoda?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=8', 'https://www.arabam.com/ikinci-el/otomobil/skoda?minYear=2010&maxYear=2023&sort=startedAt.desc&take=5
# ...

# %%
toyota = ["https://www.arabam.com/ikinci-el/otomobil/toyota?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50"]

# %%
toyota_links= []
for sayi in range(1,51):
    url = "https://www.arabam.com/ikinci-el/otomobil/toyota?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=" + str(sayi)
    toyota_links.append(url)

print(toyota_links)
# Out:
# ['https://www.arabam.com/ikinci-el/otomobil/toyota?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=1', 'https://www.arabam.com/ikinci-el/otomobil/toyota?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=2', 'https://www.arabam.com/ikinci-el/otomobil/toyota?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=3', 'https://www.arabam.com/ikinci-el/otomobil/toyota?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=4', 'https://www.arabam.com/ikinci-el/otomobil/toyota?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=5', 'https://www.arabam.com/ikinci-el/otomobil/toyota?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=6', 'https://www.arabam.com/ikinci-el/otomobil/toyota?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=7', 'https://www.arabam.com/ikinci-el/otomobil/toyota?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=8', 'https://www.arabam.com/ikinci-el/otomobil/toyota?minYear=2010&maxYear=2023&sort=startedAt.de
# ...

# %%
volkswagen = ["https://www.arabam.com/ikinci-el/otomobil/volkswagen?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50"]

# %%
vw_links = []
for sayi in range(1,51):
    url = "https://www.arabam.com/ikinci-el/otomobil/volkswagen?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=" + str(sayi)
    vw_links.append(url)

print(vw_links)
# Out:
# ['https://www.arabam.com/ikinci-el/otomobil/volkswagen?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=1', 'https://www.arabam.com/ikinci-el/otomobil/volkswagen?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=2', 'https://www.arabam.com/ikinci-el/otomobil/volkswagen?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=3', 'https://www.arabam.com/ikinci-el/otomobil/volkswagen?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=4', 'https://www.arabam.com/ikinci-el/otomobil/volkswagen?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=5', 'https://www.arabam.com/ikinci-el/otomobil/volkswagen?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=6', 'https://www.arabam.com/ikinci-el/otomobil/volkswagen?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=7', 'https://www.arabam.com/ikinci-el/otomobil/volkswagen?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=8', 'https://www.arabam.com/ikinci-el/otomobil/volkswagen?minYear
# ...

# %%
renault = ["https://www.arabam.com/ikinci-el/otomobil/renault?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50"]

# %%
renault_links=[]
for sayi in range(1,51):
    url = "https://www.arabam.com/ikinci-el/otomobil/renault?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=" + str(sayi)
    renault_links.append(url)

print(renault_links)
# Out:
# ['https://www.arabam.com/ikinci-el/otomobil/renault?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=1', 'https://www.arabam.com/ikinci-el/otomobil/renault?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=2', 'https://www.arabam.com/ikinci-el/otomobil/renault?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=3', 'https://www.arabam.com/ikinci-el/otomobil/renault?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=4', 'https://www.arabam.com/ikinci-el/otomobil/renault?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=5', 'https://www.arabam.com/ikinci-el/otomobil/renault?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=6', 'https://www.arabam.com/ikinci-el/otomobil/renault?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=7', 'https://www.arabam.com/ikinci-el/otomobil/renault?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=8', 'https://www.arabam.com/ikinci-el/otomobil/renault?minYear=2010&maxYear=2023&sort=sta
# ...

# %%
opel = ["https://www.arabam.com/ikinci-el/otomobil/opel?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50"]

# %%
opel_links= []
for sayi in range(1,51):
    url = "https://www.arabam.com/ikinci-el/otomobil/opel?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=" + str(sayi)
    opel_links.append(url)

print(opel_links)
# Out:
# ['https://www.arabam.com/ikinci-el/otomobil/opel?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=1', 'https://www.arabam.com/ikinci-el/otomobil/opel?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=2', 'https://www.arabam.com/ikinci-el/otomobil/opel?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=3', 'https://www.arabam.com/ikinci-el/otomobil/opel?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=4', 'https://www.arabam.com/ikinci-el/otomobil/opel?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=5', 'https://www.arabam.com/ikinci-el/otomobil/opel?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=6', 'https://www.arabam.com/ikinci-el/otomobil/opel?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=7', 'https://www.arabam.com/ikinci-el/otomobil/opel?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=8', 'https://www.arabam.com/ikinci-el/otomobil/opel?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=9'
# ...

# %%
fiat = ["https://www.arabam.com/ikinci-el/otomobil/fiat?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50"]

# %%
fiat_links=[]
for sayi in range(1,51):
    url = "https://www.arabam.com/ikinci-el/otomobil/fiat?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=" + str(sayi)
    fiat_links.append(url)

print(fiat_links)
# Out:
# ['https://www.arabam.com/ikinci-el/otomobil/fiat?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=1', 'https://www.arabam.com/ikinci-el/otomobil/fiat?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=2', 'https://www.arabam.com/ikinci-el/otomobil/fiat?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=3', 'https://www.arabam.com/ikinci-el/otomobil/fiat?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=4', 'https://www.arabam.com/ikinci-el/otomobil/fiat?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=5', 'https://www.arabam.com/ikinci-el/otomobil/fiat?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=6', 'https://www.arabam.com/ikinci-el/otomobil/fiat?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=7', 'https://www.arabam.com/ikinci-el/otomobil/fiat?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=8', 'https://www.arabam.com/ikinci-el/otomobil/fiat?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=9'
# ...

# %%
ford = ["https://www.arabam.com/ikinci-el/otomobil/ford?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50"]

# %%
ford_links=[]
for sayi in range(1,51):
    url = "https://www.arabam.com/ikinci-el/otomobil/ford?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=" + str(sayi)
    ford_links.append(url)

print(ford_links)
# Out:
# ['https://www.arabam.com/ikinci-el/otomobil/ford?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=1', 'https://www.arabam.com/ikinci-el/otomobil/ford?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=2', 'https://www.arabam.com/ikinci-el/otomobil/ford?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=3', 'https://www.arabam.com/ikinci-el/otomobil/ford?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=4', 'https://www.arabam.com/ikinci-el/otomobil/ford?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=5', 'https://www.arabam.com/ikinci-el/otomobil/ford?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=6', 'https://www.arabam.com/ikinci-el/otomobil/ford?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=7', 'https://www.arabam.com/ikinci-el/otomobil/ford?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=8', 'https://www.arabam.com/ikinci-el/otomobil/ford?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50&page=9'
# ...

# %%
skoda_cars=[]

for page in skoda_links:
    html=getAndParseURL(page)
    for carlink in html.findAll("td",{"class":"listing-modelname pr"}):
        skoda_cars.append("https://www.arabam.com/"+carlink.a.get("href"))
        
print(skoda_cars)
# Out:
# ['https://www.arabam.com//ilan/galeriden-satilik-skoda-octavia-1-6-tdi-elegance-cr/pars-otomotivden-skoda-octavia-1-6-tdi-elegance-cr-2013-model-kilis/23381847', 'https://www.arabam.com//ilan/sahibinden-satilik-skoda-superb-1-4-tsi-elegance/acil-sahibinden-skoda-superb-1-4-tsi-elegance-2012-model/23801739', 'https://www.arabam.com//ilan/sahibinden-satilik-skoda-octavia-1-6-tdi-style-cr/sahibinden-skoda-octavia-1-6-tdi-style-cr-2016-model/23801671', 'https://www.arabam.com//ilan/sahibinden-satilik-skoda-scala-1-6-tdi-premium/sahibinden-skoda-scala-1-6-tdi-premium-2020-model-skoda-scala-serit-takipli/23801105', 'https://www.arabam.com//ilan/sahibinden-satilik-skoda-rapid-1-0-tsi-greentec-style/sahibinden-skoda-rapid-1-0-tsi-greentec-style-2017-model/23800183', 'https://www.arabam.com//ilan/sahibinden-satilik-skoda-octavia-1-6-tdi-style/sahibinden-skoda-octavia-1-6-tdi-style-2017-model/23800422', 'https://www.arabam.com//ilan/sahibinden-satilik-skoda-superb-1-6-tdi-elegance/skoda-superb
# ...

# %%
toyota_cars=[]

for page in toyota_links:
    html=getAndParseURL(page)
    for carlink in html.findAll("td",{"class":"listing-modelname pr"}):
        toyota_cars.append("https://www.arabam.com/"+carlink.a.get("href"))
        
print(toyota_cars)
# Out:
# ['https://www.arabam.com//ilan/galeriden-satilik-toyota-yaris-1-0-life/24-bin-km-de-kazasiz-cok-temiz-mugla/23801316', 'https://www.arabam.com//ilan/sahibinden-satilik-toyota-yaris-1-0-vision/sahibinden-toyota-yaris-1-0-vision-2021-model/23447333', 'https://www.arabam.com//ilan/sahibinden-satilik-toyota-corolla-1-33-life/sahibinden-toyota-corolla-1-33-life-2016-model/23801101', 'https://www.arabam.com//ilan/sahibinden-satilik-toyota-corolla-1-4-d-4d-advance/sahibinden-toyota-corolla-1-4-d-4d-advance-2016-model/23801573', 'https://www.arabam.com//ilan/sahibinden-satilik-toyota-corolla-1-4-d-4d-touch/sahibinden-toyota-corolla-1-4-d-4d-touch-2017-model/23801731', 'https://www.arabam.com//ilan/sahibinden-satilik-toyota-verso-1-6-comfort-extra/sahibinden-toyota-verso-1-6-comfort-extra-2011-model/23801705', 'https://www.arabam.com//ilan/sahibinden-satilik-toyota-auris-1-4-d-4d-comfort-plus/sahibinden-toyota-auris-1-4-d-4d-comfort-plus-2011-model/23801405', 'https://www.arabam.com//ilan/sah
# ...

# %%
vw_cars=[]

for page in vw_links:
    html=getAndParseURL(page)
    for carlink in html.findAll("td",{"class":"listing-modelname pr"}):
        vw_cars.append("https://www.arabam.com/"+carlink.a.get("href"))
        
print(vw_cars)
# Out:
# ['https://www.arabam.com//ilan/galeriden-satilik-volkswagen-golf-1-6-tdi-bluemotion-comfortline/semih-unlu-den-2018-golf-7-5-dizel-otomatik-tek-parca-boya/23801690', 'https://www.arabam.com//ilan/galeriden-satilik-volkswagen-polo-1-0-tsi-highline/otomatik-sadece-82000-km-volkswagen-polo-1-0-tsi-highline-2018-model-zonguldak/23215104', 'https://www.arabam.com//ilan/sahibinden-satilik-volkswagen-passat-1-6-tdi-business/sahibinden-volkswagen-passat-1-6-tdi-business-2020-model-mersin/17609890', 'https://www.arabam.com//ilan/galeriden-satilik-volkswagen-vw-cc-1-4-tsi/2013-mdel-ww-cc-1-4-tsi-sportlin-otomatik-136-km-hatasiz-boyasiz/23731922', 'https://www.arabam.com//ilan/galeriden-satilik-volkswagen-polo-1-4-tdi-comfortline/2016-model-volkswagen-polo-1-4-tdi-comfortlne-73-km-dizel-boyasiz-hatasiz/23731857', 'https://www.arabam.com//ilan/galeriden-satilik-volkswagen-passat-2-0-tdi-bluemotion-highline/galeriden-volkswagen-passat-2-0-tdi-bluemotion-highline-2016-model-balikesir/23801221', 'h
# ...

# %%
renault_cars=[]

for page in renault_links:
    html=getAndParseURL(page)
    for carlink in html.findAll("td",{"class":"listing-modelname pr"}):
        renault_cars.append("https://www.arabam.com/"+carlink.a.get("href"))
        
print(renault_cars)
# Out:
# ['https://www.arabam.com//ilan/sahibinden-satilik-renault-megane-1-5-dci-touch/sahibinden-renault-megane-1-5-dci-touch-2018-model/23454118', 'https://www.arabam.com//ilan/galeriden-satilik-renault-megane-1-5-dci-icon/2016-megane-1-5-dci-icon-masaj-tesla-hayalet-ekran-yildiz-siyah/23443294', 'https://www.arabam.com//ilan/galeriden-satilik-renault-symbol-1-2-authentique/galeriden-renault-symbol-1-2-authentique-2012-model-samsun/23801494', 'https://www.arabam.com//ilan/galeriden-satilik-renault-megane-1-3-tce-joy-comfort/2021-megane-1-3-tce-joy-comfort-18-km-otomatik-teslaa-boyasiz/23732115', 'https://www.arabam.com//ilan/galeriden-satilik-renault-symbol-1-5-dci-joy/2016-model-renault-symbol-1-5-dci-joy-118-km-beyaz-hatasizz/23732027', 'https://www.arabam.com//ilan/galeriden-satilik-renault-clio-1-0-tce-touch/galeriden-renault-clio-1-0-tce-touch-2022-model-usak/23754757', 'https://www.arabam.com//ilan/sahibinden-satilik-renault-clio-1-2-joy/sahibinden-renault-clio-1-2-joy-2013-model/238
# ...

# %%
opel_cars=[]

for page in opel_links:
    html=getAndParseURL(page)
    for carlink in html.findAll("td",{"class":"listing-modelname pr"}):
        opel_cars.append("https://www.arabam.com/"+carlink.a.get("href"))
        
print(opel_cars)
# Out:
# ['https://www.arabam.com//ilan/galeriden-satilik-opel-insignia-1-6-cdti-grand-sport-design/2017-opel-insignia-1-6-cdti-grand-sport-design-cruises-takipstart-stop/22655656', 'https://www.arabam.com//ilan/galeriden-satilik-opel-astra-1-4-t-edition-plus/2020-mdel-opel-astra-1-4-t-editon-plus-43-km-otomatik-boyasizz/23732080', 'https://www.arabam.com//ilan/sahibinden-satilik-opel-corsa-1-3-cdti-enjoy/opel-corsa-1-3-cdti-ecoflex-start-stop-95-bg/23801052', 'https://www.arabam.com//ilan/sahibinden-satilik-opel-astra-1-6-cdti-sport/sahibinden-opel-astra-1-6-cdti-sport-2014-model/23801955', 'https://www.arabam.com//ilan/sahibinden-satilik-opel-astra-1-6-essentia/sahibinden-opel-astra-1-6-essentia-2012-model/23801887', 'https://www.arabam.com//ilan/sahibinden-satilik-opel-insignia-1-6-t-edition-elegance/sahibinden-opel-insignia-1-6-t-edition-elegance-2012-model/23799150', 'https://www.arabam.com//ilan/sahibinden-satilik-opel-astra-1-3-cdti-cosmo/sahibinden-opel-astra-1-3-cdti-cosmo-2012-model
# ...

# %%
fiat_cars=[]

for page in fiat_links:
    html=getAndParseURL(page)
    for carlink in html.findAll("td",{"class":"listing-modelname pr"}):
        fiat_cars.append("https://www.arabam.com/"+carlink.a.get("href"))
        
print(fiat_cars)
# Out:
# ['https://www.arabam.com//ilan/sahibinden-satilik-fiat-egea-1-4-fire-urban/sahibinden-fiat-egea-1-4-fire-urban-2021-model/22923689', 'https://www.arabam.com//ilan/galeriden-satilik-fiat-albea-sole-1-3-multijet-active/galeriden-fiat-albea-1-3-multijet-active-2010-model-zonguldak/23698502', 'https://www.arabam.com//ilan/galeriden-satilik-fiat-linea-1-3-multijet-pop/2015-linea-1-3-m-jet-pop-paket-sadece-117-bin-km-de-yeni-kasa/23801408', 'https://www.arabam.com//ilan/galeriden-satilik-fiat-punto-1-3-multijet-urban/otomobil-fiat-punto-hatchback-1-3-multijet-urban/23801332', 'https://www.arabam.com//ilan/sahibinden-satilik-fiat-punto-1-4-popstar-s-s/sahibinden-fiat-punto-1-4-popstar-s-s-2016-model/21134007', 'https://www.arabam.com//ilan/sahibinden-satilik-fiat-egea-1-4-fire-easy/sahibinden-fiat-egea-1-4-fire-easy-2020-model/23441946', 'https://www.arabam.com//ilan/sahibinden-satilik-fiat-egea-1-6-multijet-comfort/sahibinden-fiat-egea-1-6-multijet-comfort-2016-model/23801972', 'https://ww
# ...

# %%
ford_cars=[]

for page in ford_links:
    html=getAndParseURL(page)
    for carlink in html.findAll("td",{"class":"listing-modelname pr"}):
        ford_cars.append("https://www.arabam.com/"+carlink.a.get("href"))
        
print(ford_cars)
# Out:
# ['https://www.arabam.com//ilan/sahibinden-satilik-ford-focus-1-6-tdci-trend-x/sahibinden-ford-focus-1-6-tdci-trend-x-2015-model/23591690', 'https://www.arabam.com//ilan/galeriden-satilik-ford-fiesta-1-4-tdci-titanium-x/otomobil-ford-fiesta-hatchback-1-4-tdci-titanium-x/23801334', 'https://www.arabam.com//ilan/sahibinden-satilik-ford-fiesta-1-25-trend-x/sahibinden-ford-fiesta-1-25-trend-x-2016-model/23452093', 'https://www.arabam.com//ilan/sahibinden-satilik-ford-focus-1-6-tdci-trend-x/sahibinden-ford-focus-1-6-tdci-trend-x-2013-model/23801056', 'https://www.arabam.com//ilan/sahibinden-satilik-ford-c-max-1-6-tdci-titanium/sahibinden-ford-c-max-1-6-tdci-titanium-2013-model/23800643', 'https://www.arabam.com//ilan/sahibinden-satilik-ford-fiesta-1-6-ti-vct-titanium/sahibinden-ford-fiesta-1-6-ti-vct-titanium-2017-model/23801275', 'https://www.arabam.com//ilan/sahibinden-satilik-ford-focus-1-6-tdci-trend-x/sahibinden-ford-focus-1-6-tdci-trend-x-2014-model-192-000-km-beyaz/23801271', 'https
# ...

# %% [markdown]
# ## 4. Featureların Elde Edilmesi

# %%
html = getAndParseURL("https://www.arabam.com/ilan/galeriden-satilik-skoda-octavia-1-6-tdi-elegance-cr/pars-otomotivden-skoda-octavia-1-6-tdi-elegance-cr-2013-model-kilis/23381847")

# %% [markdown]
# ## 4.1.Ürün Kodu Bilgisinin Bulunması

# %%
html.find("div", {"class": "property-value"}).findAllNext()[1].text.split()
# Out:
# ['23381847']

# %% [markdown]
# ## 4.2. Marka Bilgisinin Bulunması

# %%
html.find("div", {"class": "property-value"}).findAllNext()[5].text.split()[1]
# Out:
# 'Skoda'

# %%
html.find("div", {"class": "property-value"}).findAllNext()[7].text
# Out:
# 'Skoda'

# %% [markdown]
# ## 4.3.Seri Bilgisinin Bulunması

# %%
html.find("div", {"class": "property-value"}).findAllNext()[10].text
# Out:
# 'Octavia'

# %% [markdown]
# ## 4.4.Model Bilgisinin Bulunması

# %%
html.find("div", {"class": "property-value"}).findAllNext()[13].text
# Out:
# '1.6 TDI Elegance CR'

# %% [markdown]
# ## 4.5.Yıl Bilgisinin Bulunması

# %%
html.find("div", {"class": "property-value"}).findAllNext()[16].text
# Out:
# '2013'

# %% [markdown]
# ## 4.6.Kilometre Bilgisinin Bulunması

# %%
html.find("div", {"class": "property-value"}).findAllNext()[19].text
# Out:
# '184.000 km'

# %% [markdown]
# ## 4.7.Vites Tipi Bilgisinin Bulunması

# %%
html.find("div", {"class": "property-value"}).findAllNext()[22].text
# Out:
# 'Yarı Otomatik'

# %% [markdown]
# ## 4.8.Yakıt Tipi Bilgisinin Bulunması

# %%
html.find("div", {"class": "property-value"}).findAllNext()[27].text
# Out:
# 'Dizel'

# %% [markdown]
# ## 4.9.Kasa Tipi Bilgisinin Bulunması

# %%
html.find("div", {"class": "property-value"}).findAllNext()[30].text
# Out:
# 'Hatchback/5'

# %% [markdown]
# ## 4.10.Renk Bilgisinin Bulunması

# %%
html.find("div", {"class": "property-value"}).findAllNext()[33].text
# Out:
# 'Beyaz'

# %% [markdown]
# ## 4.11.Motor Hacmi Bilgisinin Bulunması

# %%
html.find("div", {"class": "property-value"}).findAllNext()[36].text
# Out:
# '1598 cc'

# %% [markdown]
# ## 4.12.Motor Gücü Bilgisinin Bulunması

# %%
html.find("div", {"class": "property-value"}).findAllNext()[39].text
# Out:
# '105 hp'

# %% [markdown]
# ## 4.13.Çekiş Tipi Bilgisinin Bulunması

# %%
html.find("div", {"class": "property-value"}).findAllNext()[42].text
# Out:
# 'Önden Çekiş'

# %% [markdown]
# ## 4.14.Ortalama Yakıt Tüketimi Bilgisinin Bulunması

# %%
html.find("div", {"class": "property-value"}).findAllNext()[45].text
# Out:
# '3,9 lt'

# %% [markdown]
# ## 4.15.Yakıt Deposu Hacmi (LT) Bilgisinin Bulunması

# %%
html.find("div", {"class": "property-value"}).findAllNext()[48].text
# Out:
# '50 lt'

# %% [markdown]
# ## 4.16.Boya-Değişen Bilgisinin Bulunması

# %%
html.find("div", {"class": "property-value"}).findAllNext()[51].text
# Out:
# 'Belirtilmemiş'

# %% [markdown]
# ## 4.17.Takasa Uygunluk Bilgisinin Bulunması

# %%
html.find("div", {"class": "property-value"}).findAllNext()[54].text
# Out:
# 'Takasa Uygun'

# %% [markdown]
# ## 4.18.Kim Tarafından Satıldığının Bilgisinin Bulunması

# %%
html.find("div", {"class": "property-value"}).findAllNext()[57].text
# Out:
# 'Galeriden'

# %% [markdown]
# ## 4.19.Fiyat Bilgisinin Bulunması

# %%
html.find("div", {"class": "product-price-container"}).findAllNext()[1].text.split()[0]
# Out:
# '855.000'

# %% [markdown]
# ## 5. Arabalara Ait Bilgilerin DataFrame Olarak Elde Edilmesi

# %% [markdown]
# ## 5.1. Skoda İçin DF Oluşturulması

# %%
skoda_features = []
for link in skoda_cars:
    html = getAndParseURL(link)
    try:
        ürün_kodu = html.find("div", {"class": "property-value"}).findAllNext()[1].text.split()
    except:
        ürün_kodu = np.nan
    try:
        marka = html.find("div", {"class": "property-value"}).findAllNext()[7].text
    except:
        marka = np.nan
    try:
        seri = html.find("div", {"class": "property-value"}).findAllNext()[10].text
    except:
        seri = np.nan
    try:
        model = html.find("div", {"class": "property-value"}).findAllNext()[13].text
    except:
        model = np.nan
    try:
        sene = html.find("div", {"class": "property-value"}).findAllNext()[16].text
    except:
        sene = np.nan
    try:
        km = html.find("div", {"class": "property-value"}).findAllNext()[19].text
    except:
        km = np.nan
    try:
        vites = html.find("div", {"class": "property-value"}).findAllNext()[22].text
    except:
        vites = np.nan
    try:
        yakıt = html.find("div", {"class": "property-value"}).findAllNext()[27].text
    except:
        yakıt = np.nan
    try:
        kasa = html.find("div", {"class": "property-value"}).findAllNext()[30].text
    except:
        kasa = np.nan
    try:
        renk = html.find("div", {"class": "property-value"}).findAllNext()[33].text
    except:
        renk = np.nan
    try:
        motor_hacmi = html.find("div", {"class": "property-value"}).findAllNext()[36].text
    except:
        motor_hacmi = np.nan
    try:
        motor_gücü = html.find("div", {"class": "property-value"}).findAllNext()[39].text
    except:
        motor_gücü = np.nan
    try:
       çekiş_tipi = html.find("div", {"class": "property-value"}).findAllNext()[42].text
    except:
        çekiş_tipi = np.nan
    try:
        ortalama_yakıt_tüketimi = html.find("div", {"class": "property-value"}).findAllNext()[45].text
    except:
        ortalama_yakıt_tüketimi = np.nan
    try:
        depo_hacmi = html.find("div", {"class": "property-value"}).findAllNext()[48].text
    except:
        depo_hacmi = np.nan
    try:
        boya_değişen = html.find("div", {"class": "property-value"}).findAllNext()[51].text
    except:
        boya_değişen = np.nan
    try:
        takas = html.find("div", {"class": "property-value"}).findAllNext()[54].text
    except:
        takas = np.nan
    try:
        satıcı = html.find("div", {"class": "property-value"}).findAllNext()[57].text
    except:
        satıcı = np.nan
    try:
        fiyat = html.find("div", {"class": "product-price-container"}).findAllNext()[1].text.split()[0]
    except:
        fiyat = np.nan
        
    skoda_features.append([ürün_kodu,marka,seri,model,sene,km,vites,yakıt,kasa,renk,motor_hacmi,motor_gücü,çekiş_tipi,ortalama_yakıt_tüketimi,depo_hacmi,boya_değişen,takas,satıcı,fiyat])
    time.sleep(2)


df_columns = ["Ürün Kodu", "Marka","Seri","Model","Araç Yılı","Kilometre","Vites Tipi","Yakıt Tipi","Kasa Tipi","Renk","Motor Hacmi","Motor Gücü","Çekiş Tipi","Ortalama Yakıt Tüketimi","Depo Hacmi","Boya/Değişen Bilgisi","Takas Bilgisi","Satıcı","Fiyat"]

skoda_df = pd.DataFrame.from_records(skoda_features, columns=df_columns)

skoda_df
# Out:
#        Ürün Kodu  Marka     Seri                   Model Araç Yılı  \
# 0     [23381847]  Skoda  Octavia     1.6 TDI Elegance CR      2013
# 1     [23801739]  Skoda   SuperB        1.4 TSI Elegance      2012
# 2     [23801671]  Skoda  Octavia        1.6 TDI Style CR      2016
# 3     [23801105]  Skoda    Scala         1.6 TDI Premium      2020
# 4     [23800183]  Skoda    Rapid  1.0 TSI GreenTec Style      2017
# ...          ...    ...      ...                     ...       ...
# 1290  [23456719]  Skoda  Octavia        1.6 TDI Style CR      2015
# 1291  [23074829]  Skoda  Octavia         1.6 TDI Optimal      2018
# 1292  [23071427]  Skoda  Octavia           1.5 TSI Sport      2019
# 1293  [23453019]  Skoda  Octavia         1.6 TDI Optimal      2014
# 1294  [23455153]  Skoda   SuperB          1.4 TSI Active      2017
#
#        Kilometre     Vites Tipi    Yakıt Tipi    Kasa Tipi         Renk  \
# 0     184.000 km  Yarı Otomatik         Dizel  Hatchback/5        Beyaz
# ...

# %% [markdown]
# ## 5.2.Toyota İçin DF Oluşturulması

# %%
toyota_features = []
for link in toyota_cars:
    html = getAndParseURL(link)
    try:
        ürün_kodu = html.find("div", {"class": "property-value"}).findAllNext()[1].text.split()
    except:
        ürün_kodu = np.nan
    try:
        marka = html.find("div", {"class": "property-value"}).findAllNext()[7].text
    except:
        marka = np.nan
    try:
        seri = html.find("div", {"class": "property-value"}).findAllNext()[10].text
    except:
        seri = np.nan
    try:
        model = html.find("div", {"class": "property-value"}).findAllNext()[13].text
    except:
        model = np.nan
    try:
        sene = html.find("div", {"class": "property-value"}).findAllNext()[16].text
    except:
        sene = np.nan
    try:
        km = html.find("div", {"class": "property-value"}).findAllNext()[19].text
    except:
        km = np.nan
    try:
        vites = html.find("div", {"class": "property-value"}).findAllNext()[22].text
    except:
        vites = np.nan
    try:
        yakıt = html.find("div", {"class": "property-value"}).findAllNext()[27].text
    except:
        yakıt = np.nan
    try:
        kasa = html.find("div", {"class": "property-value"}).findAllNext()[30].text
    except:
        kasa = np.nan
    try:
        renk = html.find("div", {"class": "property-value"}).findAllNext()[33].text
    except:
        renk = np.nan
    try:
        motor_hacmi = html.find("div", {"class": "property-value"}).findAllNext()[36].text
    except:
        motor_hacmi = np.nan
    try:
        motor_gücü = html.find("div", {"class": "property-value"}).findAllNext()[39].text
    except:
        motor_gücü = np.nan
    try:
       çekiş_tipi = html.find("div", {"class": "property-value"}).findAllNext()[42].text
    except:
        çekiş_tipi = np.nan
    try:
        ortalama_yakıt_tüketimi = html.find("div", {"class": "property-value"}).findAllNext()[45].text
    except:
        ortalama_yakıt_tüketimi = np.nan
    try:
        depo_hacmi = html.find("div", {"class": "property-value"}).findAllNext()[48].text
    except:
        depo_hacmi = np.nan
    try:
        boya_değişen = html.find("div", {"class": "property-value"}).findAllNext()[51].text
    except:
        boya_değişen = np.nan
    try:
        takas = html.find("div", {"class": "property-value"}).findAllNext()[54].text
    except:
        takas = np.nan
    try:
        satıcı = html.find("div", {"class": "property-value"}).findAllNext()[57].text
    except:
        satıcı = np.nan
    try:
        fiyat = html.find("div", {"class": "product-price-container"}).findAllNext()[1].text.split()[0]
    except:
        fiyat = np.nan
        
    toyota_features.append([ürün_kodu,marka,seri,model,sene,km,vites,yakıt,kasa,renk,motor_hacmi,motor_gücü,çekiş_tipi,ortalama_yakıt_tüketimi,depo_hacmi,boya_değişen,takas,satıcı,fiyat])
    time.sleep(1)


df_columns = ["Ürün Kodu", "Marka","Seri","Model","Araç Yılı","Kilometre","Vites Tipi","Yakıt Tipi","Kasa Tipi","Renk","Motor Hacmi","Motor Gücü","Çekiş Tipi","Ortalama Yakıt Tüketimi","Depo Hacmi","Boya/Değişen Bilgisi","Takas Bilgisi","Satıcı","Fiyat"]

toyota_df = pd.DataFrame.from_records(toyota_features, columns=df_columns)
# Out:
# ['https://www.arabam.com/ikinci-el/otomobil/toyota?minYear=2010&maxYear=2023&sort=startedAt.desc&take=50']

# %%
toyota_df
# Out:
#        Ürün Kodu   Marka     Seri               Model Araç Yılı   Kilometre  \
# 0     [23801316]  Toyota    Yaris            1.0 Life      2013   24.800 km
# 1     [23447333]  Toyota    Yaris          1.0 Vision      2021   28.700 km
# 2     [23801101]  Toyota  Corolla           1.33 Life      2016  192.000 km
# 3     [23801573]  Toyota  Corolla    1.4 D-4D Advance      2016   58.000 km
# 4     [23801731]  Toyota  Corolla      1.4 D-4D Touch      2017  166.000 km
# ...          ...     ...      ...                 ...       ...         ...
# 2487  [23453137]  Toyota  Corolla           1.33 Life      2017   38.500 km
# 2488  [23453926]  Toyota    Auris        1.33 Comfort      2012   91.000 km
# 2489  [23452928]  Toyota  Corolla           1.5 Dream      2021   18.301 km
# 2490  [23453677]  Toyota  Corolla  1.6 Passion X-Pack      2020   14.500 km
# 2491  [23453306]  Toyota    Auris           1.33 Life      2014   75.000 km
#
# ...

# %% [markdown]
# ## 5.3.Volkswagen İçin DF oluşturulması

# %%
vw_features = []
for link in vw_cars:
    html = getAndParseURL(link)
    try:
        ürün_kodu = html.find("div", {"class": "property-value"}).findAllNext()[1].text.split()
    except:
        ürün_kodu = np.nan
    try:
        marka = html.find("div", {"class": "property-value"}).findAllNext()[7].text
    except:
        marka = np.nan
    try:
        seri = html.find("div", {"class": "property-value"}).findAllNext()[10].text
    except:
        seri = np.nan
    try:
        model = html.find("div", {"class": "property-value"}).findAllNext()[13].text
    except:
        model = np.nan
    try:
        sene = html.find("div", {"class": "property-value"}).findAllNext()[16].text
    except:
        sene = np.nan
    try:
        km = html.find("div", {"class": "property-value"}).findAllNext()[19].text
    except:
        km = np.nan
    try:
        vites = html.find("div", {"class": "property-value"}).findAllNext()[22].text
    except:
        vites = np.nan
    try:
        yakıt = html.find("div", {"class": "property-value"}).findAllNext()[27].text
    except:
        yakıt = np.nan
    try:
        kasa = html.find("div", {"class": "property-value"}).findAllNext()[30].text
    except:
        kasa = np.nan
    try:
        renk = html.find("div", {"class": "property-value"}).findAllNext()[33].text
    except:
        renk = np.nan
    try:
        motor_hacmi = html.find("div", {"class": "property-value"}).findAllNext()[36].text
    except:
        motor_hacmi = np.nan
    try:
        motor_gücü = html.find("div", {"class": "property-value"}).findAllNext()[39].text
    except:
        motor_gücü = np.nan
    try:
       çekiş_tipi = html.find("div", {"class": "property-value"}).findAllNext()[42].text
    except:
        çekiş_tipi = np.nan
    try:
        ortalama_yakıt_tüketimi = html.find("div", {"class": "property-value"}).findAllNext()[45].text
    except:
        ortalama_yakıt_tüketimi = np.nan
    try:
        depo_hacmi = html.find("div", {"class": "property-value"}).findAllNext()[48].text
    except:
        depo_hacmi = np.nan
    try:
        boya_değişen = html.find("div", {"class": "property-value"}).findAllNext()[51].text
    except:
        boya_değişen = np.nan
    try:
        takas = html.find("div", {"class": "property-value"}).findAllNext()[54].text
    except:
        takas = np.nan
    try:
        satıcı = html.find("div", {"class": "property-value"}).findAllNext()[57].text
    except:
        satıcı = np.nan
    try:
        fiyat = html.find("div", {"class": "product-price-container"}).findAllNext()[1].text.split()[0]
    except:
        fiyat = np.nan
        
    vw_features.append([ürün_kodu,marka,seri,model,sene,km,vites,yakıt,kasa,renk,motor_hacmi,motor_gücü,çekiş_tipi,ortalama_yakıt_tüketimi,depo_hacmi,boya_değişen,takas,satıcı,fiyat])
    time.sleep(1)


df_columns = ["Ürün Kodu", "Marka","Seri","Model","Araç Yılı","Kilometre","Vites Tipi","Yakıt Tipi","Kasa Tipi","Renk","Motor Hacmi","Motor Gücü","Çekiş Tipi","Ortalama Yakıt Tüketimi","Depo Hacmi","Boya/Değişen Bilgisi","Takas Bilgisi","Satıcı","Fiyat"]

vw_df = pd.DataFrame.from_records(vw_features, columns=df_columns)

# %%
vw_df
# Out:
#        Ürün Kodu       Marka    Seri                           Model  \
# 0     [23801690]  Volkswagen    Golf  1.6 TDi BlueMotion Comfortline
# 1     [23215104]  Volkswagen    Polo                1.0 TSi Highline
# 2     [17609890]  Volkswagen  Passat                1.6 TDi Business
# 3     [23731922]  Volkswagen   VW CC                         1.4 TSi
# 4     [23731857]  Volkswagen    Polo             1.4 TDi Comfortline
# ...          ...         ...     ...                             ...
# 2495  [23705511]  Volkswagen  Passat    1.4 TSi BlueMotion Trendline
# 2496  [23707320]  Volkswagen    Polo               1.2 TDi Trendline
# 2497  [23708932]  Volkswagen  Passat     2.0 TDi BlueMotion Highline
# 2498  [23708918]  Volkswagen   Jetta                1.2 TSi Highline
# 2499  [23708397]  Volkswagen    Polo               1.2 TDi Trendline
#
#      Araç Yılı   Kilometre     Vites Tipi Yakıt Tipi    Kasa Tipi  \
# 0         2018  161.000 km  Yarı Otomatik      Dizel  Hatchback/5
# ...

# %% [markdown]
# ## 5.4.Renault İçin DF Oluşturulması

# %%
renault_features = []
for link in renault_cars:
    html = getAndParseURL(link)
    try:
        ürün_kodu = html.find("div", {"class": "property-value"}).findAllNext()[1].text.split()
    except:
        ürün_kodu = np.nan
    try:
        marka = html.find("div", {"class": "property-value"}).findAllNext()[7].text
    except:
        marka = np.nan
    try:
        seri = html.find("div", {"class": "property-value"}).findAllNext()[10].text
    except:
        seri = np.nan
    try:
        model = html.find("div", {"class": "property-value"}).findAllNext()[13].text
    except:
        model = np.nan
    try:
        sene = html.find("div", {"class": "property-value"}).findAllNext()[16].text
    except:
        sene = np.nan
    try:
        km = html.find("div", {"class": "property-value"}).findAllNext()[19].text
    except:
        km = np.nan
    try:
        vites = html.find("div", {"class": "property-value"}).findAllNext()[22].text
    except:
        vites = np.nan
    try:
        yakıt = html.find("div", {"class": "property-value"}).findAllNext()[27].text
    except:
        yakıt = np.nan
    try:
        kasa = html.find("div", {"class": "property-value"}).findAllNext()[30].text
    except:
        kasa = np.nan
    try:
        renk = html.find("div", {"class": "property-value"}).findAllNext()[33].text
    except:
        renk = np.nan
    try:
        motor_hacmi = html.find("div", {"class": "property-value"}).findAllNext()[36].text
    except:
        motor_hacmi = np.nan
    try:
        motor_gücü = html.find("div", {"class": "property-value"}).findAllNext()[39].text
    except:
        motor_gücü = np.nan
    try:
       çekiş_tipi = html.find("div", {"class": "property-value"}).findAllNext()[42].text
    except:
        çekiş_tipi = np.nan
    try:
        ortalama_yakıt_tüketimi = html.find("div", {"class": "property-value"}).findAllNext()[45].text
    except:
        ortalama_yakıt_tüketimi = np.nan
    try:
        depo_hacmi = html.find("div", {"class": "property-value"}).findAllNext()[48].text
    except:
        depo_hacmi = np.nan
    try:
        boya_değişen = html.find("div", {"class": "property-value"}).findAllNext()[51].text
    except:
        boya_değişen = np.nan
    try:
        takas = html.find("div", {"class": "property-value"}).findAllNext()[54].text
    except:
        takas = np.nan
    try:
        satıcı = html.find("div", {"class": "property-value"}).findAllNext()[57].text
    except:
        satıcı = np.nan
    try:
        fiyat = html.find("div", {"class": "product-price-container"}).findAllNext()[1].text.split()[0]
    except:
        fiyat = np.nan
        
    renault_features.append([ürün_kodu,marka,seri,model,sene,km,vites,yakıt,kasa,renk,motor_hacmi,motor_gücü,çekiş_tipi,ortalama_yakıt_tüketimi,depo_hacmi,boya_değişen,takas,satıcı,fiyat])
    time.sleep(1)


df_columns = ["Ürün Kodu", "Marka","Seri","Model","Araç Yılı","Kilometre","Vites Tipi","Yakıt Tipi","Kasa Tipi","Renk","Motor Hacmi","Motor Gücü","Çekiş Tipi","Ortalama Yakıt Tüketimi","Depo Hacmi","Boya/Değişen Bilgisi","Takas Bilgisi","Satıcı","Fiyat"]

renault_df = pd.DataFrame.from_records(renault_features, columns=df_columns)

renault_df
# Out:
#        Ürün Kodu    Marka     Seri                Model Araç Yılı   Kilometre  \
# 0     [23454118]  Renault   Megane        1.5 dCi Touch      2018  122.850 km
# 1     [23443294]  Renault   Megane         1.5 dCi Icon      2016  158.000 km
# 2     [23801494]  Renault   Symbol      1.2 Authentique      2012  350.000 km
# 3     [23732115]  Renault   Megane  1.3 TCe Joy Comfort      2021   18.000 km
# 4     [23732027]  Renault   Symbol          1.5 dCi Joy      2016  110.000 km
# ...          ...      ...      ...                  ...       ...         ...
# 2495  [23731351]  Renault     Clio          1.5 dCi Joy      2015  275.000 km
# 2496  [23729165]  Renault     Clio      1.5 dCi Extreme      2011  141.000 km
# 2497  [23383895]  Renault   Symbol          1.5 dCi Joy      2018  160.000 km
# 2498  [22969016]  Renault   Symbol        1.5 dCi Touch      2018  124.000 km
# 2499  [23731775]  Renault  Fluence          1.5 dCi Joy      2013  173.000 km
#
# ...

# %% [markdown]
# ## 5.5.Opel İçin DF Oluşturulması

# %%
opel_features = []
for link in opel_cars:
    html = getAndParseURL(link)
    try:
        ürün_kodu = html.find("div", {"class": "property-value"}).findAllNext()[1].text.split()
    except:
        ürün_kodu = np.nan
    try:
        marka = html.find("div", {"class": "property-value"}).findAllNext()[7].text
    except:
        marka = np.nan
    try:
        seri = html.find("div", {"class": "property-value"}).findAllNext()[10].text
    except:
        seri = np.nan
    try:
        model = html.find("div", {"class": "property-value"}).findAllNext()[13].text
    except:
        model = np.nan
    try:
        sene = html.find("div", {"class": "property-value"}).findAllNext()[16].text
    except:
        sene = np.nan
    try:
        km = html.find("div", {"class": "property-value"}).findAllNext()[19].text
    except:
        km = np.nan
    try:
        vites = html.find("div", {"class": "property-value"}).findAllNext()[22].text
    except:
        vites = np.nan
    try:
        yakıt = html.find("div", {"class": "property-value"}).findAllNext()[27].text
    except:
        yakıt = np.nan
    try:
        kasa = html.find("div", {"class": "property-value"}).findAllNext()[30].text
    except:
        kasa = np.nan
    try:
        renk = html.find("div", {"class": "property-value"}).findAllNext()[33].text
    except:
        renk = np.nan
    try:
        motor_hacmi = html.find("div", {"class": "property-value"}).findAllNext()[36].text
    except:
        motor_hacmi = np.nan
    try:
        motor_gücü = html.find("div", {"class": "property-value"}).findAllNext()[39].text
    except:
        motor_gücü = np.nan
    try:
       çekiş_tipi = html.find("div", {"class": "property-value"}).findAllNext()[42].text
    except:
        çekiş_tipi = np.nan
    try:
        ortalama_yakıt_tüketimi = html.find("div", {"class": "property-value"}).findAllNext()[45].text
    except:
        ortalama_yakıt_tüketimi = np.nan
    try:
        depo_hacmi = html.find("div", {"class": "property-value"}).findAllNext()[48].text
    except:
        depo_hacmi = np.nan
    try:
        boya_değişen = html.find("div", {"class": "property-value"}).findAllNext()[51].text
    except:
        boya_değişen = np.nan
    try:
        takas = html.find("div", {"class": "property-value"}).findAllNext()[54].text
    except:
        takas = np.nan
    try:
        satıcı = html.find("div", {"class": "property-value"}).findAllNext()[57].text
    except:
        satıcı = np.nan
    try:
        fiyat = html.find("div", {"class": "product-price-container"}).findAllNext()[1].text.split()[0]
    except:
        fiyat = np.nan
        
    opel_features.append([ürün_kodu,marka,seri,model,sene,km,vites,yakıt,kasa,renk,motor_hacmi,motor_gücü,çekiş_tipi,ortalama_yakıt_tüketimi,depo_hacmi,boya_değişen,takas,satıcı,fiyat])
    time.sleep(1)


df_columns = ["Ürün Kodu", "Marka","Seri","Model","Araç Yılı","Kilometre","Vites Tipi","Yakıt Tipi","Kasa Tipi","Renk","Motor Hacmi","Motor Gücü","Çekiş Tipi","Ortalama Yakıt Tüketimi","Depo Hacmi","Boya/Değişen Bilgisi","Takas Bilgisi","Satıcı","Fiyat"]

opel_df = pd.DataFrame.from_records(opel_features, columns=df_columns)

opel_df
# Out:
#        Ürün Kodu Marka      Seri                        Model Araç Yılı  \
# 0     [22655656]  Opel  Insignia  1.6 CDTI Grand Sport Design      2017
# 1     [23732080]  Opel     Astra           1.4 T Edition Plus      2020
# 2     [23801052]  Opel     Corsa               1.3 CDTI Enjoy      2012
# 3     [23801955]  Opel     Astra               1.6 CDTI Sport      2014
# 4     [23801887]  Opel     Astra                 1.6 Essentia      2012
# ...          ...   ...       ...                          ...       ...
# 2495  [23615941]  Opel     Astra       1.3 CDTI ecoFLEX Sport      2011
# 2496  [23618279]  Opel     Corsa            1.2 Turbo Edition      2022
# 2497  [23616578]  Opel     Corsa                 1.2 Essentia      2012
# 2498  [23615772]  Opel     Astra               1.3 CDTI Sport      2012
# 2499  [22640535]  Opel  Insignia               1.6 CDTI Cosmo      2016
#
#        Kilometre     Vites Tipi    Yakıt Tipi    Kasa Tipi         Renk  \
# ...

# %% [markdown]
# Opel için robot değilim yazısına tıklanması isteniyor

# %% [markdown]
# ## 5.6.Fiat İçin Df Oluşturulması

# %%
fiat_features = []
for link in fiat_cars:
    html = getAndParseURL(link)
    try:
        ürün_kodu = html.find("div", {"class": "property-value"}).findAllNext()[1].text.split()
    except:
        ürün_kodu = np.nan
    try:
        marka = html.find("div", {"class": "property-value"}).findAllNext()[7].text
    except:
        marka = np.nan
    try:
        seri = html.find("div", {"class": "property-value"}).findAllNext()[10].text
    except:
        seri = np.nan
    try:
        model = html.find("div", {"class": "property-value"}).findAllNext()[13].text
    except:
        model = np.nan
    try:
        sene = html.find("div", {"class": "property-value"}).findAllNext()[16].text
    except:
        sene = np.nan
    try:
        km = html.find("div", {"class": "property-value"}).findAllNext()[19].text
    except:
        km = np.nan
    try:
        vites = html.find("div", {"class": "property-value"}).findAllNext()[22].text
    except:
        vites = np.nan
    try:
        yakıt = html.find("div", {"class": "property-value"}).findAllNext()[27].text
    except:
        yakıt = np.nan
    try:
        kasa = html.find("div", {"class": "property-value"}).findAllNext()[30].text
    except:
        kasa = np.nan
    try:
        renk = html.find("div", {"class": "property-value"}).findAllNext()[33].text
    except:
        renk = np.nan
    try:
        motor_hacmi = html.find("div", {"class": "property-value"}).findAllNext()[36].text
    except:
        motor_hacmi = np.nan
    try:
        motor_gücü = html.find("div", {"class": "property-value"}).findAllNext()[39].text
    except:
        motor_gücü = np.nan
    try:
       çekiş_tipi = html.find("div", {"class": "property-value"}).findAllNext()[42].text
    except:
        çekiş_tipi = np.nan
    try:
        ortalama_yakıt_tüketimi = html.find("div", {"class": "property-value"}).findAllNext()[45].text
    except:
        ortalama_yakıt_tüketimi = np.nan
    try:
        depo_hacmi = html.find("div", {"class": "property-value"}).findAllNext()[48].text
    except:
        depo_hacmi = np.nan
    try:
        boya_değişen = html.find("div", {"class": "property-value"}).findAllNext()[51].text
    except:
        boya_değişen = np.nan
    try:
        takas = html.find("div", {"class": "property-value"}).findAllNext()[54].text
    except:
        takas = np.nan
    try:
        satıcı = html.find("div", {"class": "property-value"}).findAllNext()[57].text
    except:
        satıcı = np.nan
    try:
        fiyat = html.find("div", {"class": "product-price-container"}).findAllNext()[1].text.split()[0]
    except:
        fiyat = np.nan
        
    fiat_features.append([ürün_kodu,marka,seri,model,sene,km,vites,yakıt,kasa,renk,motor_hacmi,motor_gücü,çekiş_tipi,ortalama_yakıt_tüketimi,depo_hacmi,boya_değişen,takas,satıcı,fiyat])
    time.sleep(1)


df_columns = ["Ürün Kodu", "Marka","Seri","Model","Araç Yılı","Kilometre","Vites Tipi","Yakıt Tipi","Kasa Tipi","Renk","Motor Hacmi","Motor Gücü","Çekiş Tipi","Ortalama Yakıt Tüketimi","Depo Hacmi","Boya/Değişen Bilgisi","Takas Bilgisi","Satıcı","Fiyat"]

fiat_df = pd.DataFrame.from_records(fiat_features, columns=df_columns)

fiat_df
# Out:
#        Ürün Kodu Marka   Seri                     Model Araç Yılı   Kilometre  \
# 0     [22923689]  Fiat   Egea            1.4 Fire Urban      2021   44.000 km
# 1     [23698502]  Fiat  Albea  Sole 1.3 Multijet Active      2010  160.000 km
# 2     [23801408]  Fiat  Linea          1.3 Multijet Pop      2015  117.000 km
# 3     [23801332]  Fiat  Punto        1.3 Multijet Urban      2014   91.953 km
# 4     [21134007]  Fiat  Punto           1.4 Popstar S&S      2016   99.100 km
# ...          ...   ...    ...                       ...       ...         ...
# 2495  [23687503]  Fiat   Egea             1.4 Fire Easy      2019   68.000 km
# 2496  [23687440]  Fiat  Linea          1.3 Multijet Pop      2016  161.000 km
# 2497  [23289677]  Fiat  Punto              1.4 Easy S&S      2013  194.800 km
# 2498  [23687024]  Fiat  Linea      1.3 Multijet Dynamic      2011  122.000 km
# 2499  [23684899]  Fiat   Egea             1.4 Fire Easy      2018   47.400 km
#
# ...

# %% [markdown]
# ## 5.7. Ford İçin DF Oluşturulması

# %%
ford_features = []
for link in ford_cars:
    html = getAndParseURL(link)
    try:
        ürün_kodu = html.find("div", {"class": "property-value"}).findAllNext()[1].text.split()
    except:
        ürün_kodu = np.nan
    try:
        marka = html.find("div", {"class": "property-value"}).findAllNext()[7].text
    except:
        marka = np.nan
    try:
        seri = html.find("div", {"class": "property-value"}).findAllNext()[10].text
    except:
        seri = np.nan
    try:
        model = html.find("div", {"class": "property-value"}).findAllNext()[13].text
    except:
        model = np.nan
    try:
        sene = html.find("div", {"class": "property-value"}).findAllNext()[16].text
    except:
        sene = np.nan
    try:
        km = html.find("div", {"class": "property-value"}).findAllNext()[19].text
    except:
        km = np.nan
    try:
        vites = html.find("div", {"class": "property-value"}).findAllNext()[22].text
    except:
        vites = np.nan
    try:
        yakıt = html.find("div", {"class": "property-value"}).findAllNext()[27].text
    except:
        yakıt = np.nan
    try:
        kasa = html.find("div", {"class": "property-value"}).findAllNext()[30].text
    except:
        kasa = np.nan
    try:
        renk = html.find("div", {"class": "property-value"}).findAllNext()[33].text
    except:
        renk = np.nan
    try:
        motor_hacmi = html.find("div", {"class": "property-value"}).findAllNext()[36].text
    except:
        motor_hacmi = np.nan
    try:
        motor_gücü = html.find("div", {"class": "property-value"}).findAllNext()[39].text
    except:
        motor_gücü = np.nan
    try:
       çekiş_tipi = html.find("div", {"class": "property-value"}).findAllNext()[42].text
    except:
        çekiş_tipi = np.nan
    try:
        ortalama_yakıt_tüketimi = html.find("div", {"class": "property-value"}).findAllNext()[45].text
    except:
        ortalama_yakıt_tüketimi = np.nan
    try:
        depo_hacmi = html.find("div", {"class": "property-value"}).findAllNext()[48].text
    except:
        depo_hacmi = np.nan
    try:
        boya_değişen = html.find("div", {"class": "property-value"}).findAllNext()[51].text
    except:
        boya_değişen = np.nan
    try:
        takas = html.find("div", {"class": "property-value"}).findAllNext()[54].text
    except:
        takas = np.nan
    try:
        satıcı = html.find("div", {"class": "property-value"}).findAllNext()[57].text
    except:
        satıcı = np.nan
    try:
        fiyat = html.find("div", {"class": "product-price-container"}).findAllNext()[1].text.split()[0]
    except:
        fiyat = np.nan
        
    ford_features.append([ürün_kodu,marka,seri,model,sene,km,vites,yakıt,kasa,renk,motor_hacmi,motor_gücü,çekiş_tipi,ortalama_yakıt_tüketimi,depo_hacmi,boya_değişen,takas,satıcı,fiyat])
    time.sleep(1)


df_columns = ["Ürün Kodu", "Marka","Seri","Model","Araç Yılı","Kilometre","Vites Tipi","Yakıt Tipi","Kasa Tipi","Renk","Motor Hacmi","Motor Gücü","Çekiş Tipi","Ortalama Yakıt Tüketimi","Depo Hacmi","Boya/Değişen Bilgisi","Takas Bilgisi","Satıcı","Fiyat"]

ford_df = pd.DataFrame.from_records(ford_features, columns=df_columns)

ford_df
# Out:
#        Ürün Kodu Marka    Seri                Model Araç Yılı   Kilometre  \
# 0     [23591690]  Ford   Focus     1.6 TDCi Trend X      2015  150.500 km
# 1     [23801334]  Ford  Fiesta  1.4 TDCi Titanium X      2011  183.665 km
# 2     [23452093]  Ford  Fiesta         1.25 Trend X      2016  131.000 km
# 3     [23801056]  Ford   Focus     1.6 TDCi Trend X      2013  130.000 km
# 4     [23800643]  Ford   C-Max    1.6 TDCi Titanium      2013  122.000 km
# ...          ...   ...     ...                  ...       ...         ...
# 2495  [23600950]  Ford  Fiesta       1.4 Titanium X      2012  161.000 km
# 2496  [23602581]  Ford   Focus    1.6 TDCi Titanium      2011  181.000 km
# 2497  [23601026]  Ford  Fiesta  1.4 TDCi Titanium X      2011  190.000 km
# 2498  [23600105]  Ford  Fiesta    1.0 GTDi Titanium      2014   31.000 km
# 2499  [23600642]  Ford   Focus     1.5 TDCi Trend X      2016   66.000 km
#
#          Vites Tipi    Yakıt Tipi    Kasa Tipi           Renk Motor Hacmi  \
# ...

# %% [markdown]
# ## 6.Boş Değer Kontrolü

# %%
skoda_df.isna().sum()
# Out:
# Ürün Kodu                  0
# Marka                      0
# Seri                       0
# Model                      0
# Araç Yılı                  0
# Kilometre                  0
# Vites Tipi                 0
# Yakıt Tipi                 0
# Kasa Tipi                  0
# Renk                       0
# Motor Hacmi                0
# Motor Gücü                 0
# Çekiş Tipi                 0
# Ortalama Yakıt Tüketimi    0
# Depo Hacmi                 0
# Boya/Değişen Bilgisi       0
# Takas Bilgisi              0
# Satıcı                     0
# Fiyat                      0
# dtype: int64

# %%
toyota_df.isna().sum()
# Out:
# Ürün Kodu                  0
# Marka                      0
# Seri                       0
# Model                      0
# Araç Yılı                  0
# Kilometre                  0
# Vites Tipi                 0
# Yakıt Tipi                 0
# Kasa Tipi                  0
# Renk                       0
# Motor Hacmi                0
# Motor Gücü                 0
# Çekiş Tipi                 0
# Ortalama Yakıt Tüketimi    0
# Depo Hacmi                 0
# Boya/Değişen Bilgisi       0
# Takas Bilgisi              0
# Satıcı                     0
# Fiyat                      0
# dtype: int64

# %%
vw_df.isna().sum()
# Out:
# Ürün Kodu                  7
# Marka                      7
# Seri                       7
# Model                      7
# Araç Yılı                  7
# Kilometre                  7
# Vites Tipi                 7
# Yakıt Tipi                 7
# Kasa Tipi                  7
# Renk                       7
# Motor Hacmi                7
# Motor Gücü                 7
# Çekiş Tipi                 7
# Ortalama Yakıt Tüketimi    7
# Depo Hacmi                 7
# Boya/Değişen Bilgisi       7
# Takas Bilgisi              7
# Satıcı                     7
# Fiyat                      7
# dtype: int64

# %%
renault_df.isna().sum()
# Out:
# Ürün Kodu                  19
# Marka                      19
# Seri                       19
# Model                      19
# Araç Yılı                  19
# Kilometre                  19
# Vites Tipi                 19
# Yakıt Tipi                 19
# Kasa Tipi                  19
# Renk                       19
# Motor Hacmi                19
# Motor Gücü                 19
# Çekiş Tipi                 19
# Ortalama Yakıt Tüketimi    19
# Depo Hacmi                 19
# Boya/Değişen Bilgisi       19
# Takas Bilgisi              19
# Satıcı                     19
# Fiyat                      19
# dtype: int64

# %%
opel_df.isna().sum()
# Out:
# Ürün Kodu                  31
# Marka                      31
# Seri                       31
# Model                      31
# Araç Yılı                  31
# Kilometre                  31
# Vites Tipi                 31
# Yakıt Tipi                 31
# Kasa Tipi                  31
# Renk                       31
# Motor Hacmi                31
# Motor Gücü                 31
# Çekiş Tipi                 31
# Ortalama Yakıt Tüketimi    31
# Depo Hacmi                 31
# Boya/Değişen Bilgisi       31
# Takas Bilgisi              31
# Satıcı                     31
# Fiyat                      31
# dtype: int64

# %%
fiat_df.isna().sum()
# Out:
# Ürün Kodu                  32
# Marka                      32
# Seri                       32
# Model                      32
# Araç Yılı                  32
# Kilometre                  32
# Vites Tipi                 32
# Yakıt Tipi                 32
# Kasa Tipi                  32
# Renk                       32
# Motor Hacmi                32
# Motor Gücü                 32
# Çekiş Tipi                 32
# Ortalama Yakıt Tüketimi    32
# Depo Hacmi                 32
# Boya/Değişen Bilgisi       32
# Takas Bilgisi              32
# Satıcı                     32
# Fiyat                      32
# dtype: int64

# %%
ford_df.isna().sum()
# Out:
# Ürün Kodu                  23
# Marka                      23
# Seri                       23
# Model                      23
# Araç Yılı                  23
# Kilometre                  23
# Vites Tipi                 23
# Yakıt Tipi                 23
# Kasa Tipi                  23
# Renk                       23
# Motor Hacmi                23
# Motor Gücü                 23
# Çekiş Tipi                 23
# Ortalama Yakıt Tüketimi    23
# Depo Hacmi                 23
# Boya/Değişen Bilgisi       23
# Takas Bilgisi              23
# Satıcı                     23
# Fiyat                      23
# dtype: int64

# %% [markdown]
# ## 7.Ürün Kodu Sütununu Düzeltme İşlemi

# %%
# "Ürün Kodu" sütunundaki listelerden parantezleri kaldırma ve DataFrame'i güncelleme
skoda_df['Ürün Kodu'] = skoda_df['Ürün Kodu'].apply(lambda x: x[0] if isinstance(x, list) and len(x) > 0 else x)


print(skoda_df["Ürün Kodu"])
# Out:
# 0       23381847
# 1       23801739
# 2       23801671
# 3       23801105
# 4       23800183
#           ...
# 1290    23456719
# 1291    23074829
# 1292    23071427
# 1293    23453019
# 1294    23455153
# Name: Ürün Kodu, Length: 1295, dtype: object

# %%
toyota_df['Ürün Kodu'] = toyota_df['Ürün Kodu'].apply(lambda x: x[0] if isinstance(x, list) and len(x) > 0 else x)


print(toyota_df["Ürün Kodu"])
# Out:
# 0       23801316
# 1       23447333
# 2       23801101
# 3       23801573
# 4       23801731
#           ...
# 2487    23453137
# 2488    23453926
# 2489    23452928
# 2490    23453677
# 2491    23453306
# Name: Ürün Kodu, Length: 2492, dtype: object

# %%
vw_df['Ürün Kodu'] = vw_df['Ürün Kodu'].apply(lambda x: x[0] if isinstance(x, list) and len(x) > 0 else x)


print(vw_df["Ürün Kodu"])
# Out:
# 0       23801690
# 1       23215104
# 2       17609890
# 3       23731922
# 4       23731857
#           ...
# 2495    23705511
# 2496    23707320
# 2497    23708932
# 2498    23708918
# 2499    23708397
# Name: Ürün Kodu, Length: 2500, dtype: object

# %%
renault_df['Ürün Kodu'] = renault_df['Ürün Kodu'].apply(lambda x: x[0] if isinstance(x, list) and len(x) > 0 else x)


print(renault_df["Ürün Kodu"])
# Out:
# 0       23454118
# 1       23443294
# 2       23801494
# 3       23732115
# 4       23732027
#           ...
# 2495    23731351
# 2496    23729165
# 2497    23383895
# 2498    22969016
# 2499    23731775
# Name: Ürün Kodu, Length: 2500, dtype: object

# %%
opel_df['Ürün Kodu'] = opel_df['Ürün Kodu'].apply(lambda x: x[0] if isinstance(x, list) and len(x) > 0 else x)


print(opel_df["Ürün Kodu"])
# Out:
# 0       22655656
# 1       23732080
# 2       23801052
# 3       23801955
# 4       23801887
#           ...
# 2495    23615941
# 2496    23618279
# 2497    23616578
# 2498    23615772
# 2499    22640535
# Name: Ürün Kodu, Length: 2500, dtype: object

# %%
fiat_df['Ürün Kodu'] = fiat_df['Ürün Kodu'].apply(lambda x: x[0] if isinstance(x, list) and len(x) > 0 else x)


print(fiat_df["Ürün Kodu"])
# Out:
# 0       22923689
# 1       23698502
# 2       23801408
# 3       23801332
# 4       21134007
#           ...
# 2495    23687503
# 2496    23687440
# 2497    23289677
# 2498    23687024
# 2499    23684899
# Name: Ürün Kodu, Length: 2500, dtype: object

# %%
ford_df['Ürün Kodu'] = ford_df['Ürün Kodu'].apply(lambda x: x[0] if isinstance(x, list) and len(x) > 0 else x)


print(ford_df["Ürün Kodu"])
# Out:
# 0       23591690
# 1       23801334
# 2       23452093
# 3       23801056
# 4       23800643
#           ...
# 2495    23600950
# 2496    23602581
# 2497    23601026
# 2498    23600105
# 2499    23600642
# Name: Ürün Kodu, Length: 2500, dtype: object

# %% [markdown]
# ## 8. Duplicate Veri Kontrolü

# %%
# SkodaDataFrame'inizdeki duplicate verileri bulma
duplicate_rows = skoda_df[skoda_df.duplicated()]

# Toplam duplicate satır sayısını bulma
total_duplicates = duplicate_rows.shape[0]

print(f"Skoda DataFrame İçin Toplam Duplicate Satır Sayısı: {total_duplicates}")
# Out:
# Skoda DataFrame İçin Toplam Duplicate Satır Sayısı: 0

# %%
# Toyota DataFrame'inizdeki duplicate verileri bulma
duplicate_rows = toyota_df[toyota_df.duplicated()]

# Toplam duplicate satır sayısını bulma
total_duplicates = duplicate_rows.shape[0]

print(f"Toyota DataFrame İçin Toplam Duplicate Satır Sayısı: {total_duplicates}")
# Out:
# Toyota DataFrame İçin Toplam Duplicate Satır Sayısı: 0

# %%
# Volkswagen DataFrame'inizdeki duplicate verileri bulma
duplicate_rows = vw_df[vw_df.duplicated()]

# Toplam duplicate satır sayısını bulma
total_duplicates = duplicate_rows.shape[0]

print(f"Volkswagen DataFrame İçin Toplam Duplicate Satır Sayısı: {total_duplicates}")
# Out:
# Volkswagen DataFrame İçin Toplam Duplicate Satır Sayısı: 6

# %%
vw_df[vw_df.duplicated()]
# Out:
#      Ürün Kodu Marka Seri Model Araç Yılı Kilometre Vites Tipi Yakıt Tipi  \
# 23         NaN   NaN  NaN   NaN       NaN       NaN        NaN        NaN
# 25         NaN   NaN  NaN   NaN       NaN       NaN        NaN        NaN
# 30         NaN   NaN  NaN   NaN       NaN       NaN        NaN        NaN
# 36         NaN   NaN  NaN   NaN       NaN       NaN        NaN        NaN
# 740        NaN   NaN  NaN   NaN       NaN       NaN        NaN        NaN
# 1607       NaN   NaN  NaN   NaN       NaN       NaN        NaN        NaN
#
#      Kasa Tipi Renk Motor Hacmi Motor Gücü Çekiş Tipi Ortalama Yakıt Tüketimi  \
# 23         NaN  NaN         NaN        NaN        NaN                     NaN
# 25         NaN  NaN         NaN        NaN        NaN                     NaN
# 30         NaN  NaN         NaN        NaN        NaN                     NaN
# 36         NaN  NaN         NaN        NaN        NaN                     NaN
# ...

# %%
# Renault DataFrame'inizdeki duplicate verileri bulma
duplicate_rows = renault_df[renault_df.duplicated()]

# Toplam duplicate satır sayısını bulma
total_duplicates = duplicate_rows.shape[0]

print(f"Renault DataFrame İçin Toplam Duplicate Satır Sayısı: {total_duplicates}")
# Out:
# Renault DataFrame İçin Toplam Duplicate Satır Sayısı: 20

# %%
renault_df[renault_df.duplicated()]
# Out:
#      Ürün Kodu    Marka    Seri                    Model Araç Yılı  \
# 26         NaN      NaN     NaN                      NaN       NaN
# 32         NaN      NaN     NaN                      NaN       NaN
# 40         NaN      NaN     NaN                      NaN       NaN
# 45         NaN      NaN     NaN                      NaN       NaN
# 50    23798816  Renault  Symbol  1.2 Authentique Edition      2012
# 62         NaN      NaN     NaN                      NaN       NaN
# 87         NaN      NaN     NaN                      NaN       NaN
# 134        NaN      NaN     NaN                      NaN       NaN
# 419        NaN      NaN     NaN                      NaN       NaN
# 432        NaN      NaN     NaN                      NaN       NaN
# 562        NaN      NaN     NaN                      NaN       NaN
# 569        NaN      NaN     NaN                      NaN       NaN
# 650   23779931  Renault    Clio           1.2 Turbo Icon      2015
# ...

# %%
# Opel DataFrame'inizdeki duplicate verileri bulma
duplicate_rows = opel_df[opel_df.duplicated()]

# Toplam duplicate satır sayısını bulma
total_duplicates = duplicate_rows.shape[0]

print(f"Opel DataFrame İçin Toplam Duplicate Satır Sayısı: {total_duplicates}")
# Out:
# Opel DataFrame İçin Toplam Duplicate Satır Sayısı: 31

# %%
opel_df[opel_df.duplicated()]
# Out:
#      Ürün Kodu Marka   Seri           Model Araç Yılı   Kilometre Vites Tipi  \
# 79         NaN   NaN    NaN             NaN       NaN         NaN        NaN
# 80         NaN   NaN    NaN             NaN       NaN         NaN        NaN
# 94         NaN   NaN    NaN             NaN       NaN         NaN        NaN
# 135        NaN   NaN    NaN             NaN       NaN         NaN        NaN
# 207        NaN   NaN    NaN             NaN       NaN         NaN        NaN
# 353        NaN   NaN    NaN             NaN       NaN         NaN        NaN
# 441        NaN   NaN    NaN             NaN       NaN         NaN        NaN
# 506        NaN   NaN    NaN             NaN       NaN         NaN        NaN
# 522        NaN   NaN    NaN             NaN       NaN         NaN        NaN
# 577        NaN   NaN    NaN             NaN       NaN         NaN        NaN
# 580        NaN   NaN    NaN             NaN       NaN         NaN        NaN
# ...

# %%
# Fiat DataFrame'inizdeki duplicate verileri bulma
duplicate_rows = fiat_df[fiat_df.duplicated()]

# Toplam duplicate satır sayısını bulma
total_duplicates = duplicate_rows.shape[0]

print(f"Fiat DataFrame İçin Toplam Duplicate Satır Sayısı: {total_duplicates}")
# Out:
# Fiat DataFrame İçin Toplam Duplicate Satır Sayısı: 33

# %%
fiat_df[fiat_df.duplicated()]
# Out:
#      Ürün Kodu Marka  Seri              Model Araç Yılı   Kilometre  \
# 21         NaN   NaN   NaN                NaN       NaN         NaN
# 80         NaN   NaN   NaN                NaN       NaN         NaN
# 137        NaN   NaN   NaN                NaN       NaN         NaN
# 138        NaN   NaN   NaN                NaN       NaN         NaN
# 163        NaN   NaN   NaN                NaN       NaN         NaN
# 373        NaN   NaN   NaN                NaN       NaN         NaN
# 389        NaN   NaN   NaN                NaN       NaN         NaN
# 450   23771335  Fiat  Egea  1.3 Multijet Easy      2020  138.037 km
# 451   23768047  Fiat  Egea  1.3 Multijet Easy      2020  109.037 km
# 457        NaN   NaN   NaN                NaN       NaN         NaN
# 461        NaN   NaN   NaN                NaN       NaN         NaN
# 469        NaN   NaN   NaN                NaN       NaN         NaN
# 621        NaN   NaN   NaN                NaN       NaN         NaN
# ...

# %%
# Ford DataFrame'inizdeki duplicate verileri bulma
duplicate_rows = ford_df[ford_df.duplicated()]

# Toplam duplicate satır sayısını bulma
total_duplicates = duplicate_rows.shape[0]

print(f"Ford DataFrame İçin Toplam Duplicate Satır Sayısı: {total_duplicates}")
# Out:
# Ford DataFrame İçin Toplam Duplicate Satır Sayısı: 22

# %%
ford_df[ford_df.duplicated()]
# Out:
#      Ürün Kodu Marka Seri Model Araç Yılı Kilometre Vites Tipi Yakıt Tipi  \
# 15         NaN   NaN  NaN   NaN       NaN       NaN        NaN        NaN
# 62         NaN   NaN  NaN   NaN       NaN       NaN        NaN        NaN
# 158        NaN   NaN  NaN   NaN       NaN       NaN        NaN        NaN
# 285        NaN   NaN  NaN   NaN       NaN       NaN        NaN        NaN
# 322        NaN   NaN  NaN   NaN       NaN       NaN        NaN        NaN
# 337        NaN   NaN  NaN   NaN       NaN       NaN        NaN        NaN
# 388        NaN   NaN  NaN   NaN       NaN       NaN        NaN        NaN
# 606        NaN   NaN  NaN   NaN       NaN       NaN        NaN        NaN
# 802        NaN   NaN  NaN   NaN       NaN       NaN        NaN        NaN
# 806        NaN   NaN  NaN   NaN       NaN       NaN        NaN        NaN
# 938        NaN   NaN  NaN   NaN       NaN       NaN        NaN        NaN
# 1195       NaN   NaN  NaN   NaN       NaN       NaN        NaN        NaN
# ...

# %% [markdown]
# ## 9. NaN Değerlerinin Çıkarılması

# %%
vw_df.dropna()
# Out:
#      Ürün Kodu       Marka    Seri                           Model Araç Yılı  \
# 0     23801690  Volkswagen    Golf  1.6 TDi BlueMotion Comfortline      2018
# 1     23215104  Volkswagen    Polo                1.0 TSi Highline      2018
# 2     17609890  Volkswagen  Passat                1.6 TDi Business      2020
# 3     23731922  Volkswagen   VW CC                         1.4 TSi      2013
# 4     23731857  Volkswagen    Polo             1.4 TDi Comfortline      2016
# ...        ...         ...     ...                             ...       ...
# 2495  23705511  Volkswagen  Passat    1.4 TSi BlueMotion Trendline      2017
# 2496  23707320  Volkswagen    Polo               1.2 TDi Trendline      2013
# 2497  23708932  Volkswagen  Passat     2.0 TDi BlueMotion Highline      2013
# 2498  23708918  Volkswagen   Jetta                1.2 TSi Highline      2012
# 2499  23708397  Volkswagen    Polo               1.2 TDi Trendline      2013
#
# ...

# %%
renault_df.dropna()
# Out:
#      Ürün Kodu    Marka     Seri                Model Araç Yılı   Kilometre  \
# 0     23454118  Renault   Megane        1.5 dCi Touch      2018  122.850 km
# 1     23443294  Renault   Megane         1.5 dCi Icon      2016  158.000 km
# 2     23801494  Renault   Symbol      1.2 Authentique      2012  350.000 km
# 3     23732115  Renault   Megane  1.3 TCe Joy Comfort      2021   18.000 km
# 4     23732027  Renault   Symbol          1.5 dCi Joy      2016  110.000 km
# ...        ...      ...      ...                  ...       ...         ...
# 2495  23731351  Renault     Clio          1.5 dCi Joy      2015  275.000 km
# 2496  23729165  Renault     Clio      1.5 dCi Extreme      2011  141.000 km
# 2497  23383895  Renault   Symbol          1.5 dCi Joy      2018  160.000 km
# 2498  22969016  Renault   Symbol        1.5 dCi Touch      2018  124.000 km
# 2499  23731775  Renault  Fluence          1.5 dCi Joy      2013  173.000 km
#
# ...

# %%
opel_df.dropna()
# Out:
#      Ürün Kodu Marka      Seri                        Model Araç Yılı  \
# 0     22655656  Opel  Insignia  1.6 CDTI Grand Sport Design      2017
# 1     23732080  Opel     Astra           1.4 T Edition Plus      2020
# 2     23801052  Opel     Corsa               1.3 CDTI Enjoy      2012
# 3     23801955  Opel     Astra               1.6 CDTI Sport      2014
# 4     23801887  Opel     Astra                 1.6 Essentia      2012
# ...        ...   ...       ...                          ...       ...
# 2495  23615941  Opel     Astra       1.3 CDTI ecoFLEX Sport      2011
# 2496  23618279  Opel     Corsa            1.2 Turbo Edition      2022
# 2497  23616578  Opel     Corsa                 1.2 Essentia      2012
# 2498  23615772  Opel     Astra               1.3 CDTI Sport      2012
# 2499  22640535  Opel  Insignia               1.6 CDTI Cosmo      2016
#
#        Kilometre     Vites Tipi    Yakıt Tipi    Kasa Tipi         Renk  \
# ...

# %%
fiat_df.dropna()
# Out:
#      Ürün Kodu Marka   Seri                     Model Araç Yılı   Kilometre  \
# 0     22923689  Fiat   Egea            1.4 Fire Urban      2021   44.000 km
# 1     23698502  Fiat  Albea  Sole 1.3 Multijet Active      2010  160.000 km
# 2     23801408  Fiat  Linea          1.3 Multijet Pop      2015  117.000 km
# 3     23801332  Fiat  Punto        1.3 Multijet Urban      2014   91.953 km
# 4     21134007  Fiat  Punto           1.4 Popstar S&S      2016   99.100 km
# ...        ...   ...    ...                       ...       ...         ...
# 2495  23687503  Fiat   Egea             1.4 Fire Easy      2019   68.000 km
# 2496  23687440  Fiat  Linea          1.3 Multijet Pop      2016  161.000 km
# 2497  23289677  Fiat  Punto              1.4 Easy S&S      2013  194.800 km
# 2498  23687024  Fiat  Linea      1.3 Multijet Dynamic      2011  122.000 km
# 2499  23684899  Fiat   Egea             1.4 Fire Easy      2018   47.400 km
#
# ...

# %%
ford_df.dropna()
# Out:
#      Ürün Kodu Marka    Seri                Model Araç Yılı   Kilometre  \
# 0     23591690  Ford   Focus     1.6 TDCi Trend X      2015  150.500 km
# 1     23801334  Ford  Fiesta  1.4 TDCi Titanium X      2011  183.665 km
# 2     23452093  Ford  Fiesta         1.25 Trend X      2016  131.000 km
# 3     23801056  Ford   Focus     1.6 TDCi Trend X      2013  130.000 km
# 4     23800643  Ford   C-Max    1.6 TDCi Titanium      2013  122.000 km
# ...        ...   ...     ...                  ...       ...         ...
# 2495  23600950  Ford  Fiesta       1.4 Titanium X      2012  161.000 km
# 2496  23602581  Ford   Focus    1.6 TDCi Titanium      2011  181.000 km
# 2497  23601026  Ford  Fiesta  1.4 TDCi Titanium X      2011  190.000 km
# 2498  23600105  Ford  Fiesta    1.0 GTDi Titanium      2014   31.000 km
# 2499  23600642  Ford   Focus     1.5 TDCi Trend X      2016   66.000 km
#
#          Vites Tipi    Yakıt Tipi    Kasa Tipi           Renk Motor Hacmi  \
# ...

# %% [markdown]
# ## 10.DataFramelerin Kayıt Edilmesi

# %%
skoda_df.to_csv("Skoda_DataFrame.csv")

# %%
toyota_df.to_csv("Toyota_DataFrame.csv")

# %%
vw_df.to_csv("Volkswagen_DataFrame.csv")

# %%
renault_df.to_csv("Renault_DataFrame.csv")

# %%
opel_df.to_csv("Opel_DataFrame.csv")

# %%
fiat_df.to_csv("Fiat_DataFrame.csv")

# %%
ford_df.to_csv("Ford_DataFrame.csv")
